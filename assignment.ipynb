# %%
# Import statement
from ultralytics import YOLO

# Loading a pre - trained ultralytics model
model = YOLO(RF'models\yolov8m.pt')

# Inference on custom videos
results = model.track(source = rf"D:\Multi-Camera-Person-Tracking-and-Re-Identification\videos\output\allVideos.avi", show = True, save = True, tracker = "bytetrack.yaml")
# Out:
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1375) D:\Multi-Camera-Person-Tracking-and-Re-Identification\videos\output\allVideos.avi: 384x640 3 persons, 1 umbrella, 1 laptop, 700.4ms
# video 1/1 (frame 2/1375) D:\Multi-Camera-Person-Tracking-and-Re-Identification\videos\output\allVideos.avi: 384x640 3 persons, 1 bed, 1 laptop, 1090.7ms
# ...
